# %%
import requests

# %%
response = requests.get("https://wttr.in/Sinaia")

# %%
response.json
# Out:
# <bound method Response.json of <Response [200]>>

# %%
print(response.text)
# Out:
# Weather report: Sinaia
#
#       \   /     Sunny
#        .-.      26 °C
#     ― (   ) ―   ↑ 4 km/h
#        `-’      10 km
#       /   \     0.0 mm
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Thu 03 Jul ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │     \   /     Sunny          │     \   /     Sunny          │     \   /     Sunny          │     \   /     Sunny          │
# │      .-.      22 °C          │      .-.      25 °C          │      .-.      +24(25) °C     │      .-.      18 °C          │
# │   ― (   ) ―   → 1-2 km/h     │   ― (   ) ―   ↑ 3 km/h       │   ― (   ) ―   ↑ 3 km/h       │   ― (   ) ―   → 2-4 km/h     │
# ...
